# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# http://pandas.pydata.org/
#
# Pandas es la extensión logica de numpy al mundo del Análisis de datos.
#
# De forma muy general, Pandas extrae la figura del Dataframe conocida por aquellos que usan R a python.
#
# Un pandas dataframe es una tabla, lo que es una hoja de excel, con filas y columnas.
#
# En pandas cada columna es una Serie que esta definida con un numpy array por debajo.

# %% [markdown]
# # Creacion

# %% [markdown]
# pandas puede leer archivos de muchos tipos, csv, json, excel entre otros

# %%
rick_morty = pd.DataFrame(
    {
        "nombre": ["Rick", "Morty"],
        "apellido": ["Sanchez", "Smith"],
        "edad": [60, 14],
    }
)

rick_morty
# Out:
#   nombre apellido  edad
# 0   Rick  Sanchez    60
# 1  Morty    Smith    14

# %%
rick_morty = pd.DataFrame(
    [
        ["Rick", "Sanchez", 60],
        ["Morty", "Smith", 14]
    ], columns = ["nombre", "apellido", "edad"]
)
rick_morty
# Out:
#   nombre apellido  edad
# 0   Rick  Sanchez    60
# 1  Morty    Smith    14

# %%
type(rick_morty.nombre)
# Out:
# pandas.core.series.Series

# %%
# !type -n 5 "primary_results.csv"
# Out:
# state,state_abbreviation,county,fips,party,candidate,votes,fraction_votes
# Alabama,AL,Autauga,1001.0,Democrat,Bernie Sanders,544,0.182
# Alabama,AL,Autauga,1001.0,Democrat,Hillary Clinton,2387,0.8
# Alabama,AL,Baldwin,1003.0,Democrat,Bernie Sanders,2694,0.32899999999999996
# Alabama,AL,Baldwin,1003.0,Democrat,Hillary Clinton,5290,0.647
# Alabama,AL,Barbour,1005.0,Democrat,Bernie Sanders,222,0.078
# Alabama,AL,Barbour,1005.0,Democrat,Hillary Clinton,2567,0.9059999999999999
# Alabama,AL,Bibb,1007.0,Democrat,Bernie Sanders,246,0.19699999999999998
# Alabama,AL,Bibb,1007.0,Democrat,Hillary Clinton,942,0.755
# Alabama,AL,Blount,1009.0,Democrat,Bernie Sanders,395,0.386
# Alabama,AL,Blount,1009.0,Democrat,Hillary Clinton,564,0.551
# Alabama,AL,Bullock,1011.0,Democrat,Bernie Sanders,178,0.066
# Alabama,AL,Bullock,1011.0,Democrat,Hillary Clinton,2451,0.9129999999999999
# Alabama,AL,Butler,1013.0,Democrat,Bernie Sanders,156,0.065
# Alabama,AL,Butler,1013.0,Democrat,Hillary Clinton,2196,0.9209999999999999
# Alabama,AL,Calhoun,1015.0,Democrat,Bernie Sanders,1425,0.218
# Alabama,AL,Calhoun,1015.0,Democrat,Hillary Clinton,5011,0.765
# Alabama,AL,Chambers,1017.0,Democrat,Bernie Sanders,312,0.095
# Alabama,AL,Chambers,1017.0,Democrat,Hillary Clinton,2899,0.8859999999999999
# Alabama,AL,Cherokee,1019.0,Democrat,Bernie Sanders,268,0.249
# Alabama,AL,Cherokee,1019.0,Democrat,Hillary Clinton,712,0.6609999999999999
# Alabama,AL,Chilton,1021.0,Democrat,Bernie Sanders,289,0.24600000000000002
# Alabama,AL,Chilton,1021.0,Democrat,Hillary Clinton,860,0.731
# Alabama,AL,Choctaw,1023.0,Democrat,Bernie Sanders,273,0.124
# Alabama,AL,Autauga,1001.0,Republican,Ted Cruz,2482,0.205
# Alabama,AL,Baldwin,1003.0,Republican,Ben Carson,4221,0.084
# Alabama,AL,Baldwin,1003.0,Republican,Donald Trump,23618,0.469
# Alabama,AL,Baldwin,1003.0,Republican,John Kasich,2987,0.059000000000000004
# Alabama,AL,Baldwin,1003.0,Republican,Marco Rubio,9703,0.193
# Alabama,AL,Baldwin,1003.0,Republican,Ted Cruz,8571,0.17
# Alabama,AL,Barbour,1005.0,Republican,Ben Carson,417,0.122
# Alabama,AL,Barbour,1005.0,Republican,Donald Trump,1710,0.501
# Alabama,AL,Barbour,1005.0,Republican,John Kasich,123,0.036000000000000004
# Alabama,AL,Barbour,1005.0,Republican,Marco Rubio,498,0.146
# Alabama,AL,Barbour,1005.0,Republican,Ted Cruz,609,0.179
# Alabama,AL,Bibb,1007.0,Republican,Ben Carson,393,0.099
# Alabama,AL,Bibb,1007.0,Republican,Donald Trump,1959,0.494
# Alabama,AL,Bibb,1007.0,Republican,John Kasich,84,0.021
# Alabama,AL,Bibb,1007.0,Republican,Marco Rubio,444,0.11199999999999999
# Alabama,AL,Bibb,1007.0,Republican,Ted Cruz,1011,0.255
# Alabama,AL,Blount,1009.0,Republican,Ben Carson,1523,0.1
# Alabama,AL,Blount,1009.0,Republican,Donald Trump,7390,0.48700000000000004
# Alabama,AL,Blount,1009.0,Republican,John Kasich,337,0.022000000000000002
# Alabama,AL,Blount,1009.0,Republican,Marco Rubio,1843,0.122
# Alabama,AL,Blount,1009.0,Republican,Ted Cruz,3698,0.244
# Alabama,AL,Bullock,1011.0,Republican,Ben Carson,47,0.085
# Alabama,AL,Bullock,1011.0,Republican,Donald Trump,313,0.565
# Alabama,AL,Bullock,1011.0,Republican,John Kasich,23,0.042
# Alabama,AL,Bullock,1011.0,Republican,Marco Rubio,64,0.11599999999999999
# Alabama,AL,Bullock,1011.0,Republican,Ted Cruz,94,0.17
# Alabama,AL,Butler,1013.0,Republican,Ben Carson,377,0.11800000000000001
# Alabama,AL,Butler,1013.0,Republican,Donald Trump,1720,0.5379999999999999
# Alabama,AL,Butler,1013.0,Republican,John Kasich,86,0.027000000000000003
# Alabama,AL,Butler,1013.0,Republican,Marco Rubio,427,0.133
# Alabama,AL,Butler,1013.0,Republican,Ted Cruz,534,0.16699999999999998
# Alabama,AL,Calhoun,1015.0,Republican,Ben Carson,2350,0.11800000000000001
# Alabama,AL,Calhoun,1015.0,Republican,Donald Trump,8960,0.451
# Alabama,AL,Calhoun,1015.0,Republican,John Kasich,957,0.048
# Alabama,AL,Calhoun,1015.0,Republican,Marco Rubio,3251,0.163
# Alabama,AL,Calhoun,1015.0,Republican,Ted Cruz,3859,0.19399999999999998
# Alabama,AL,Chambers,1017.0,Republican,Ben Carson,595,0.131
# Alabama,AL,Chambers,1017.0,Republican,Donald Trump,2169,0.47600000000000003
# Alabama,AL,Chambers,1017.0,Republican,John Kasich,168,0.037000000000000005
# Alabama,AL,Chambers,1017.0,Republican,Marco Rubio,595,0.131
# Alabama,AL,Chambers,1017.0,Republican,Ted Cruz,914,0.2
# Alabama,AL,Cherokee,1019.0,Republican,Ben Carson,534,0.1
# Alabama,AL,Cherokee,1019.0,Republican,Donald Trump,2777,0.521
# Alabama,AL,Cherokee,1019.0,Republican,John Kasich,151,0.027999999999999997
# Alabama,AL,Cherokee,1019.0,Republican,Marco Rubio,810,0.152
# Alabama,AL,Cherokee,1019.0,Republican,Ted Cruz,921,0.17300000000000001
# Alabama,AL,Chilton,1021.0,Republican,Ben Carson,1149,0.10800000000000001
# Alabama,AL,Chilton,1021.0,Republican,Donald Trump,5273,0.493
# Alabama,AL,Chilton,1021.0,Republican,John Kasich,218,0.02
# Alabama,AL,Chilton,1021.0,Republican,Marco Rubio,1436,0.134
# Alabama,AL,Chilton,1021.0,Republican,Ted Cruz,2328,0.218
# Alabama,AL,Choctaw,1023.0,Republican,Ben Carson,169,0.079
# Alabama,AL,Choctaw,1023.0,Republican,Donald Trump,1070,0.499
# Alabama,AL,Choctaw,1023.0,Republican,John Kasich,68,0.032
# Alabama,AL,Choctaw,1023.0,Republican,Marco Rubio,315,0.147
# Alabama,AL,Choctaw,1023.0,Republican,Ted Cruz,451,0.21
# Alabama,AL,Clarke,1025.0,Republican,Ben Carson,410,0.08900000000000001
# Alabama,AL,Clarke,1025.0,Republican,Donald Trump,2308,0.502
# Alabama,AL,Clarke,1025.0,Republican,John Kasich,125,0.027000000000000003
# Alabama,AL,Clarke,1025.0,Republican,Marco Rubio,805,0.175
# Alabama,AL,Clarke,1025.0,Republican,Ted Cruz,886,0.193
# Alabama,AL,Clay,1027.0,Republican,Ben Carson,492,0.122
# Alabama,AL,Clay,1027.0,Republican,Donald Trump,1920,0.47600000000000003
# Alabama,AL,Clay,1027.0,Republican,John Kasich,125,0.031
# Alabama,AL,Clay,1027.0,Republican,Marco Rubio,505,0.125
# Alabama,AL,Clay,1027.0,Republican,Ted Cruz,836,0.207
# Alabama,AL,Cleburne,1029.0,Republican,Ben Carson,437,0.1
# Alabama,AL,Cleburne,1029.0,Republican,Donald Trump,2120,0.483
# Alabama,AL,Cleburne,1029.0,Republican,John Kasich,106,0.024
# Alabama,AL,Cleburne,1029.0,Republican,Marco Rubio,598,0.136
# Alabama,AL,Cleburne,1029.0,Republican,Ted Cruz,928,0.21100000000000002
# Alabama,AL,Coffee,1031.0,Republican,Ben Carson,1368,0.132
# Alabama,AL,Coffee,1031.0,Republican,Donald Trump,4304,0.414
# Alabama,AL,Coffee,1031.0,Republican,John Kasich,377,0.036000000000000004
# Alabama,AL,Coffee,1031.0,Republican,Marco Rubio,1608,0.155
# Alabama,AL,Coffee,1031.0,Republican,Ted Cruz,2421,0.233
# Alabama,AL,Colbert,1033.0,Republican,Ben Carson,884,0.109
# Alabama,AL,Colbert,1033.0,Republican,Donald Trump,3858,0.474
# Alabama,AL,Colbert,1033.0,Republican,John Kasich,250,0.031
# Alabama,AL,Colbert,1033.0,Republican,Marco Rubio,1443,0.177
# Alabama,AL,Colbert,1033.0,Republican,Ted Cruz,1601,0.19699999999999998
# Alabama,AL,Elmore,1051.0,Republican,Ben Carson,2630,0.14800000000000002
# Alabama,AL,Elmore,1051.0,Republican,Donald Trump,8525,0.478
# Alabama,AL,Elmore,1051.0,Republican,John Kasich,634,0.036000000000000004
# Alabama,AL,Elmore,1051.0,Republican,Marco Rubio,2387,0.134
# Alabama,AL,Elmore,1051.0,Republican,Ted Cruz,3236,0.182
# Alabama,AL,Escambia,1053.0,Republican,Ben Carson,585,0.102
# Alabama,AL,Escambia,1053.0,Republican,Donald Trump,2817,0.493
# Alabama,AL,Escambia,1053.0,Republican,John Kasich,194,0.034
# Alabama,AL,Escambia,1053.0,Republican,Marco Rubio,1028,0.18
# Alabama,AL,Escambia,1053.0,Republican,Ted Cruz,978,0.171
# Alabama,AL,Etowah,1055.0,Republican,Ben Carson,2098,0.11199999999999999
# Alabama,AL,Etowah,1055.0,Republican,Donald Trump,8657,0.461
# Alabama,AL,Etowah,1055.0,Republican,John Kasich,616,0.033
# Alabama,AL,Etowah,1055.0,Republican,Marco Rubio,3155,0.168
# Alabama,AL,Etowah,1055.0,Republican,Ted Cruz,3891,0.207
# Alabama,AL,Fayette,1057.0,Republican,Ben Carson,488,0.098
# Alabama,AL,Fayette,1057.0,Republican,Donald Trump,2479,0.499
# Alabama,AL,Fayette,1057.0,Republican,John Kasich,124,0.025
# Alabama,AL,Fayette,1057.0,Republican,Marco Rubio,663,0.133
# Alabama,AL,Fayette,1057.0,Republican,Ted Cruz,1043,0.21
# Alabama,AL,Franklin,1059.0,Republican,Ben Carson,388,0.09300000000000001
# Alabama,AL,Franklin,1059.0,Republican,Donald Trump,2155,0.515
# Alabama,AL,Franklin,1059.0,Republican,John Kasich,107,0.026000000000000002
# Alabama,AL,Franklin,1059.0,Republican,Marco Rubio,562,0.134
# Alabama,AL,Franklin,1059.0,Republican,Ted Cruz,892,0.213
# Alabama,AL,Geneva,1061.0,Republican,Ben Carson,592,0.09300000000000001
# Alabama,AL,Geneva,1061.0,Republican,Donald Trump,3106,0.486
# Alabama,AL,Geneva,1061.0,Republican,John Kasich,146,0.023
# Alabama,AL,Geneva,1061.0,Republican,Marco Rubio,829,0.13
# Alabama,AL,Geneva,1061.0,Republican,Ted Cruz,1517,0.237
# Alabama,AL,Greene,1063.0,Republican,Ben Carson,19,0.07
# Alabama,AL,Greene,1063.0,Republican,Donald Trump,147,0.5379999999999999
# Alabama,AL,Greene,1063.0,Republican,John Kasich,10,0.037000000000000005
# Alabama,AL,Greene,1063.0,Republican,Marco Rubio,33,0.121
# Alabama,AL,Greene,1063.0,Republican,Ted Cruz,59,0.21600000000000003
# Alabama,AL,Hale,1065.0,Republican,Ben Carson,88,0.078
# Alabama,AL,Hale,1065.0,Republican,Donald Trump,590,0.521
# Alabama,AL,Hale,1065.0,Republican,John Kasich,24,0.021
# Alabama,AL,Hale,1065.0,Republican,Marco Rubio,132,0.11699999999999999
# Alabama,AL,Hale,1065.0,Republican,Ted Cruz,283,0.25
# Alabama,AL,Henry,1067.0,Republican,Ben Carson,436,0.115
# Alabama,AL,Henry,1067.0,Republican,Donald Trump,1778,0.46799999999999997
# Alabama,AL,Limestone,1083.0,Republican,John Kasich,746,0.039
# Alabama,AL,Limestone,1083.0,Republican,Marco Rubio,3602,0.18899999999999997
# Alabama,AL,Limestone,1083.0,Republican,Ted Cruz,4082,0.214
# Alabama,AL,Lowndes,1085.0,Republican,Ben Carson,88,0.105
# Alabama,AL,Lowndes,1085.0,Republican,Donald Trump,500,0.595
# Alabama,AL,Lowndes,1085.0,Republican,John Kasich,26,0.031
# Alabama,AL,Lowndes,1085.0,Republican,Marco Rubio,83,0.099
# Alabama,AL,Lowndes,1085.0,Republican,Ted Cruz,137,0.163
# Alabama,AL,Macon,1087.0,Republican,Ben Carson,94,0.127
# Alabama,AL,Macon,1087.0,Republican,Donald Trump,356,0.48
# Alabama,AL,Macon,1087.0,Republican,John Kasich,39,0.053
# Alabama,AL,Macon,1087.0,Republican,Marco Rubio,92,0.124
# Alabama,AL,Macon,1087.0,Republican,Ted Cruz,147,0.198
# Alabama,AL,Madison,1089.0,Republican,Ben Carson,6293,0.096
# Alabama,AL,Madison,1089.0,Republican,Donald Trump,23791,0.36200000000000004
# Alabama,AL,Madison,1089.0,Republican,John Kasich,3919,0.06
# Alabama,AL,Madison,1089.0,Republican,Marco Rubio,17116,0.26
# Alabama,AL,Madison,1089.0,Republican,Ted Cruz,13622,0.207
# Alabama,AL,Marengo,1091.0,Republican,Ben Carson,85,0.079
# Alabama,AL,Marengo,1091.0,Republican,Donald Trump,580,0.539
# Alabama,AL,Marengo,1091.0,Republican,John Kasich,26,0.024
# Alabama,AL,Marengo,1091.0,Republican,Marco Rubio,127,0.11800000000000001
# Alabama,AL,Marengo,1091.0,Republican,Ted Cruz,228,0.212
# Alabama,AL,Marion,1093.0,Republican,Ben Carson,589,0.08900000000000001
# Alabama,AL,Marion,1093.0,Republican,Donald Trump,3503,0.529
# Alabama,AL,Marion,1093.0,Republican,John Kasich,167,0.025
# Alabama,AL,Marion,1093.0,Republican,Marco Rubio,921,0.139
# Alabama,AL,Marion,1093.0,Republican,Ted Cruz,1268,0.192
# Alabama,AL,Marshall,1095.0,Republican,Ben Carson,1813,0.098
# Alabama,AL,Marshall,1095.0,Republican,Donald Trump,9115,0.495
# Alabama,AL,Marshall,1095.0,Republican,John Kasich,595,0.032
# Alabama,AL,Marshall,1095.0,Republican,Marco Rubio,3785,0.20600000000000002
# Alabama,AL,Marshall,1095.0,Republican,Ted Cruz,2784,0.151
# Alabama,AL,Mobile,1097.0,Republican,Ben Carson,4824,0.077
# Alabama,AL,Mobile,1097.0,Republican,Donald Trump,28326,0.452
# Alabama,AL,Mobile,1097.0,Republican,John Kasich,2893,0.046
# Alabama,AL,Mobile,1097.0,Republican,Marco Rubio,11850,0.18899999999999997
# Alabama,AL,Mobile,1097.0,Republican,Ted Cruz,13458,0.215
# Alabama,AL,Monroe,1099.0,Republican,Ben Carson,373,0.099
# Alabama,AL,Monroe,1099.0,Republican,Donald Trump,1966,0.521
# Alabama,AL,Monroe,1099.0,Republican,John Kasich,108,0.028999999999999998
# Alabama,AL,Monroe,1099.0,Republican,Marco Rubio,596,0.158
# Alabama,AL,Monroe,1099.0,Republican,Ted Cruz,658,0.174
# Alabama,AL,Montgomery,1101.0,Republican,Ben Carson,3379,0.127
# Alabama,AL,Montgomery,1101.0,Republican,Donald Trump,10517,0.39399999999999996
# Alabama,AL,Montgomery,1101.0,Republican,John Kasich,1953,0.073
# Alabama,AL,Montgomery,1101.0,Republican,Marco Rubio,5570,0.209
# Alabama,AL,Montgomery,1101.0,Republican,Ted Cruz,4700,0.17600000000000002
# Alabama,AL,Morgan,1103.0,Republican,Ben Carson,2790,0.114
# Alabama,AL,Morgan,1103.0,Republican,Donald Trump,10909,0.446
# Alabama,AL,Morgan,1103.0,Republican,John Kasich,1109,0.045
# Alabama,AL,Morgan,1103.0,Republican,Marco Rubio,4488,0.183
# Alabama,AL,Morgan,1103.0,Republican,Ted Cruz,4828,0.19699999999999998
# Alabama,AL,Perry,1105.0,Republican,Ben Carson,15,0.04
# Alabama,AL,Perry,1105.0,Republican,Donald Trump,192,0.515
# Alabama,AL,Perry,1105.0,Republican,John Kasich,2,0.005
# Alabama,AL,Perry,1105.0,Republican,Marco Rubio,33,0.08800000000000001
# Alabama,AL,Perry,1105.0,Republican,Ted Cruz,123,0.33
# Alabama,AL,Pickens,1107.0,Republican,Ben Carson,287,0.113
# Alabama,AL,Pickens,1107.0,Republican,Donald Trump,1124,0.441
# Alabama,AL,Pickens,1107.0,Republican,John Kasich,65,0.025
# Alabama,AL,Pickens,1107.0,Republican,Marco Rubio,353,0.138
# Alabama,AL,Pickens,1107.0,Republican,Ted Cruz,658,0.258
# Alabama,AL,Pike,1109.0,Republican,Ben Carson,698,0.129
# Alabama,AL,Pike,1109.0,Republican,Donald Trump,2493,0.46
# Alabama,AL,Pike,1109.0,Republican,John Kasich,172,0.032
# Alabama,AL,Pike,1109.0,Republican,Marco Rubio,798,0.147
# Alabama,AL,Pike,1109.0,Republican,Ted Cruz,1092,0.201
# Alabama,AL,Randolph,1111.0,Republican,Ben Carson,426,0.09300000000000001
# Alabama,AL,Randolph,1111.0,Republican,Donald Trump,2352,0.516
# Alabama,AL,Randolph,1111.0,Republican,John Kasich,133,0.028999999999999998
# Alabama,AL,Randolph,1111.0,Republican,Marco Rubio,584,0.128
# Alabama,AL,Randolph,1111.0,Republican,Ted Cruz,942,0.207
# Alabama,AL,Russell,1113.0,Republican,Ben Carson,298,0.079
# Alabama,AL,Russell,1113.0,Republican,Donald Trump,1784,0.474
# Alabama,AL,Russell,1113.0,Republican,John Kasich,106,0.027999999999999997
# Alabama,AL,Russell,1113.0,Republican,Marco Rubio,463,0.12300000000000001
# Alabama,AL,Russell,1113.0,Republican,Ted Cruz,1016,0.27
# Alabama,AL,Shelby,1117.0,Republican,Ben Carson,5005,0.094
# Alabama,AL,Shelby,1117.0,Republican,Donald Trump,18260,0.344
# Alabama,AL,Shelby,1117.0,Republican,John Kasich,2679,0.05
# Alabama,AL,Shelby,1117.0,Republican,Marco Rubio,12213,0.23
# Alabama,AL,Shelby,1117.0,Republican,Ted Cruz,14005,0.263
# Alabama,AL,St. Clair,1115.0,Republican,Ben Carson,2093,0.109
# Alabama,AL,St. Clair,1115.0,Republican,Donald Trump,8596,0.446
# Alabama,AL,St. Clair,1115.0,Republican,John Kasich,518,0.027000000000000003
# Alabama,AL,St. Clair,1115.0,Republican,Marco Rubio,2586,0.134
# Alabama,AL,St. Clair,1115.0,Republican,Ted Cruz,5178,0.26899999999999996
# Alabama,AL,Sumter,1119.0,Republican,Ben Carson,21,0.075
# Alabama,AL,Sumter,1119.0,Republican,Donald Trump,166,0.591
# Alabama,AL,Sumter,1119.0,Republican,John Kasich,4,0.013999999999999999
# Alabama,AL,Sumter,1119.0,Republican,Marco Rubio,39,0.139
# Alabama,AL,Sumter,1119.0,Republican,Ted Cruz,45,0.16
# Alabama,AL,Talladega,1121.0,Republican,Ben Carson,1179,0.095
# Alabama,AL,Talladega,1121.0,Republican,Donald Trump,6304,0.51
# Alabama,AL,Talladega,1121.0,Republican,John Kasich,470,0.038
# Alabama,AL,Talladega,1121.0,Republican,Marco Rubio,1676,0.136
# Alabama,AL,Talladega,1121.0,Republican,Ted Cruz,2468,0.2
# Alabama,AL,Tallapoosa,1123.0,Republican,Ben Carson,1006,0.114
# Alabama,AL,Tallapoosa,1123.0,Republican,Donald Trump,4658,0.528
# Alabama,AL,Tallapoosa,1123.0,Republican,John Kasich,371,0.042
# Alabama,AL,Tallapoosa,1123.0,Republican,Marco Rubio,1289,0.146
# Alabama,AL,Tallapoosa,1123.0,Republican,Ted Cruz,1325,0.15
# Alabama,AL,Tuscaloosa,1125.0,Republican,Ben Carson,3310,0.106
# Alabama,AL,Tuscaloosa,1125.0,Republican,Donald Trump,11652,0.375
# Alabama,AL,Tuscaloosa,1125.0,Republican,John Kasich,1381,0.044000000000000004
# Alabama,AL,Tuscaloosa,1125.0,Republican,Marco Rubio,6333,0.204
# Alabama,AL,Tuscaloosa,1125.0,Republican,Ted Cruz,7789,0.25
# Alabama,AL,Walker,1127.0,Republican,Ben Carson,1369,0.09
# Alabama,AL,Walker,1127.0,Republican,Donald Trump,8394,0.551
# Alabama,AL,Walker,1127.0,Republican,John Kasich,362,0.024
# Alabama,AL,Walker,1127.0,Republican,Marco Rubio,1652,0.10800000000000001
# Alabama,AL,Walker,1127.0,Republican,Ted Cruz,3106,0.204
# Alabama,AL,Washington,1129.0,Republican,Ben Carson,152,0.064
# Alabama,AL,Washington,1129.0,Republican,Donald Trump,1269,0.537
# Alabama,AL,Washington,1129.0,Republican,John Kasich,27,0.011000000000000001
# Alabama,AL,Washington,1129.0,Republican,Marco Rubio,362,0.153
# Alabama,AL,Washington,1129.0,Republican,Ted Cruz,516,0.218
# Alabama,AL,Wilcox,1131.0,Republican,Ben Carson,44,0.083
# Alabama,AL,Wilcox,1131.0,Republican,Donald Trump,287,0.544
# Alabama,AL,Wilcox,1131.0,Republican,John Kasich,12,0.023
# Alabama,AL,Wilcox,1131.0,Republican,Marco Rubio,64,0.121
# Alabama,AL,Wilcox,1131.0,Republican,Ted Cruz,114,0.21600000000000003
# Alaska,AK,State House District 14,90200114.0,Republican,Ted Cruz,397,0.35600000000000004
# Alaska,AK,State House District 15,90200115.0,Republican,Ben Carson,31,0.124
# Alaska,AK,State House District 15,90200115.0,Republican,Donald Trump,71,0.28300000000000003
# Alaska,AK,State House District 15,90200115.0,Republican,John Kasich,7,0.027999999999999997
# Alaska,AK,State House District 15,90200115.0,Republican,Marco Rubio,34,0.135
# Alaska,AK,State House District 15,90200115.0,Republican,Ted Cruz,108,0.43
# Alaska,AK,State House District 16,90200116.0,Republican,Ben Carson,44,0.10300000000000001
# Alaska,AK,State House District 16,90200116.0,Republican,Donald Trump,139,0.326
# Alaska,AK,State House District 16,90200116.0,Republican,John Kasich,22,0.052000000000000005
# Alaska,AK,State House District 16,90200116.0,Republican,Marco Rubio,66,0.155
# Alaska,AK,State House District 16,90200116.0,Republican,Ted Cruz,155,0.364
# Alaska,AK,State House District 17,90200117.0,Republican,Ben Carson,9,0.028999999999999998
# Alaska,AK,State House District 17,90200117.0,Republican,Donald Trump,112,0.364
# Alaska,AK,State House District 17,90200117.0,Republican,John Kasich,25,0.081
# Alaska,AK,State House District 17,90200117.0,Republican,Marco Rubio,60,0.195
# Alaska,AK,State House District 17,90200117.0,Republican,Ted Cruz,102,0.331
# Alaska,AK,State House District 18,90200118.0,Republican,Ben Carson,17,0.049
# Alaska,AK,State House District 18,90200118.0,Republican,Donald Trump,126,0.365
# Alaska,AK,State House District 18,90200118.0,Republican,John Kasich,25,0.07200000000000001
# Alaska,AK,State House District 18,90200118.0,Republican,Marco Rubio,69,0.2
# Alaska,AK,State House District 18,90200118.0,Republican,Ted Cruz,108,0.313
# Alaska,AK,State House District 19,90200119.0,Republican,Ben Carson,10,0.079
# Alaska,AK,State House District 19,90200119.0,Republican,Donald Trump,48,0.37799999999999995
# Alaska,AK,State House District 19,90200119.0,Republican,John Kasich,8,0.063
# Alaska,AK,State House District 19,90200119.0,Republican,Marco Rubio,19,0.15
# Alaska,AK,State House District 19,90200119.0,Republican,Ted Cruz,42,0.331
# Alaska,AK,State House District 2,90200102.0,Republican,Ben Carson,22,0.087
# Alaska,AK,State House District 2,90200102.0,Republican,Donald Trump,90,0.35600000000000004
# Alaska,AK,State House District 2,90200102.0,Republican,John Kasich,7,0.027999999999999997
# Alaska,AK,State House District 2,90200102.0,Republican,Marco Rubio,31,0.12300000000000001
# Alaska,AK,State House District 2,90200102.0,Republican,Ted Cruz,103,0.40700000000000003
# Alaska,AK,State House District 20,90200120.0,Republican,Ben Carson,16,0.076
# Alaska,AK,State House District 20,90200120.0,Republican,Donald Trump,57,0.27
# Alaska,AK,State House District 20,90200120.0,Republican,John Kasich,24,0.114
# Alaska,AK,State House District 20,90200120.0,Republican,Marco Rubio,54,0.256
# Alaska,AK,State House District 20,90200120.0,Republican,Ted Cruz,60,0.284
# Alaska,AK,State House District 21,90200121.0,Republican,Ben Carson,38,0.081
# Alaska,AK,State House District 21,90200121.0,Republican,Donald Trump,154,0.32899999999999996
# Alaska,AK,State House District 21,90200121.0,Republican,John Kasich,28,0.06
# Wyoming,WY,Uinta,56041.0,Democrat,Bernie Sanders,5,0.556
# Wyoming,WY,Uinta,56041.0,Democrat,Hillary Clinton,4,0.444
# Wyoming,WY,Washakie,56043.0,Democrat,Bernie Sanders,1,0.33299999999999996
# Wyoming,WY,Washakie,56043.0,Democrat,Hillary Clinton,2,0.667
# Wyoming,WY,Weston,56045.0,Democrat,Bernie Sanders,1,0.5
# Wyoming,WY,Weston,56045.0,Democrat,Hillary Clinton,1,0.5
# Wyoming,WY,Albany-Natrona,95600025.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Albany-Natrona,95600025.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Albany-Natrona,95600025.0,Republican,Marco Rubio,39,0.513
# Wyoming,WY,Albany-Natrona,95600025.0,Republican,Ted Cruz,37,0.48700000000000004
# Wyoming,WY,Campbell-Johnson,95600032.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Campbell-Johnson,95600032.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Campbell-Johnson,95600032.0,Republican,Marco Rubio,0,0.0
# Wyoming,WY,Campbell-Johnson,95600032.0,Republican,Ted Cruz,68,1.0
# Wyoming,WY,Converse-Niobrara,95600034.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Converse-Niobrara,95600034.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Converse-Niobrara,95600034.0,Republican,Marco Rubio,35,0.479
# Wyoming,WY,Converse-Niobrara,95600034.0,Republican,Ted Cruz,38,0.521
# Wyoming,WY,Crook-Weston,95600033.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Crook-Weston,95600033.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Crook-Weston,95600033.0,Republican,Marco Rubio,0,0.0
# Wyoming,WY,Crook-Weston,95600033.0,Republican,Ted Cruz,27,0.466
# Wyoming,WY,Fremont-Park,95600029.0,Republican,Donald Trump,33,0.34
# Wyoming,WY,Fremont-Park,95600029.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Fremont-Park,95600029.0,Republican,Marco Rubio,0,0.0
# Wyoming,WY,Fremont-Park,95600029.0,Republican,Ted Cruz,64,0.66
# Wyoming,WY,Goshen-Platte,95600035.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Goshen-Platte,95600035.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Goshen-Platte,95600035.0,Republican,Marco Rubio,0,0.0
# Wyoming,WY,Goshen-Platte,95600035.0,Republican,Ted Cruz,83,1.0
# Wyoming,WY,Hot Springs-Washakie,95600030.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Hot Springs-Washakie,95600030.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Hot Springs-Washakie,95600030.0,Republican,Marco Rubio,0,0.0
# Wyoming,WY,Hot Springs-Washakie,95600030.0,Republican,Ted Cruz,43,1.0
# Wyoming,WY,Laramie,95600036.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Laramie,95600036.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Laramie,95600036.0,Republican,Marco Rubio,38,0.17600000000000002
# Wyoming,WY,Laramie,95600036.0,Republican,Ted Cruz,141,0.653
# Wyoming,WY,Sheridan-Big Horn,95600031.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Sheridan-Big Horn,95600031.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Sheridan-Big Horn,95600031.0,Republican,Marco Rubio,30,0.4
# Wyoming,WY,Sheridan-Big Horn,95600031.0,Republican,Ted Cruz,45,0.6
# Wyoming,WY,Sweetwater-Carbon,95600026.0,Republican,Donald Trump,16,0.18
# Wyoming,WY,Sweetwater-Carbon,95600026.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Sweetwater-Carbon,95600026.0,Republican,Marco Rubio,28,0.315
# Wyoming,WY,Sweetwater-Carbon,95600026.0,Republican,Ted Cruz,45,0.506
# Wyoming,WY,Teton-Sublette,95600028.0,Republican,Donald Trump,21,0.525
# Wyoming,WY,Teton-Sublette,95600028.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Teton-Sublette,95600028.0,Republican,Marco Rubio,19,0.475
# Wyoming,WY,Teton-Sublette,95600028.0,Republican,Ted Cruz,0,0.0
# Wyoming,WY,Uinta-Lincoln,95600027.0,Republican,Donald Trump,0,0.0
# Wyoming,WY,Uinta-Lincoln,95600027.0,Republican,John Kasich,0,0.0
# Wyoming,WY,Uinta-Lincoln,95600027.0,Republican,Marco Rubio,0,0.0
# Wyoming,WY,Uinta-Lincoln,95600027.0,Republican,Ted Cruz,53,1.0

# %%
votos_primarias_us = pd.read_csv("primary_results.csv")
votos_primarias_us
# Out:
#          state state_abbreviation          county        fips       party  \
# 0      Alabama                 AL         Autauga      1001.0    Democrat
# 1      Alabama                 AL         Autauga      1001.0    Democrat
# 2      Alabama                 AL         Baldwin      1003.0    Democrat
# 3      Alabama                 AL         Baldwin      1003.0    Democrat
# 4      Alabama                 AL         Barbour      1005.0    Democrat
# ...        ...                ...             ...         ...         ...
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#              candidate  votes  fraction_votes
# 0       Bernie Sanders    544           0.182
# 1      Hillary Clinton   2387           0.800
# 2       Bernie Sanders   2694           0.329
# 3      Hillary Clinton   5290           0.647
# 4       Bernie Sanders    222           0.078
# ...                ...    ...             ...
# 24606         Ted Cruz      0           0.000
# 24607     Donald Trump      0           0.000
# 24608      John Kasich      0           0.000
# 24609      Marco Rubio      0           0.000
# 24610         Ted Cruz     53           1.000
#
# [24611 rows x 8 columns]

# %% [markdown]
# por convención cuando se analiza un solo dataframe se suele llamar df

# %%
df = votos_primarias_us
df
# Out:
#          state state_abbreviation          county        fips       party  \
# 0      Alabama                 AL         Autauga      1001.0    Democrat
# 1      Alabama                 AL         Autauga      1001.0    Democrat
# 2      Alabama                 AL         Baldwin      1003.0    Democrat
# 3      Alabama                 AL         Baldwin      1003.0    Democrat
# 4      Alabama                 AL         Barbour      1005.0    Democrat
# ...        ...                ...             ...         ...         ...
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#              candidate  votes  fraction_votes
# 0       Bernie Sanders    544           0.182
# 1      Hillary Clinton   2387           0.800
# 2       Bernie Sanders   2694           0.329
# 3      Hillary Clinton   5290           0.647
# 4       Bernie Sanders    222           0.078
# ...                ...    ...             ...
# 24606         Ted Cruz      0           0.000
# 24607     Donald Trump      0           0.000
# 24608      John Kasich      0           0.000
# 24609      Marco Rubio      0           0.000
# 24610         Ted Cruz     53           1.000
#
# [24611 rows x 8 columns]

# %% [raw]
# # Exploración

# %% [markdown]
# `shape` nos devuelve el número de filas y columnas

# %%
df.shape
# Out:
# (24611, 8)

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
df.tail()
# Out:
#          state state_abbreviation          county        fips       party  \
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#           candidate  votes  fraction_votes
# 24606      Ted Cruz      0             0.0
# 24607  Donald Trump      0             0.0
# 24608   John Kasich      0             0.0
# 24609   Marco Rubio      0             0.0
# 24610      Ted Cruz     53             1.0

# %%
df.dtypes
# Out:
# state                  object
# state_abbreviation     object
# county                 object
# fips                  float64
# party                  object
# candidate              object
# votes                   int64
# fraction_votes        float64
# dtype: object

# %%
df.describe()
# Out:
#                fips          votes  fraction_votes
# count  2.451100e+04   24611.000000    24611.000000
# mean   2.667152e+07    2306.252773        0.304524
# std    4.200978e+07    9861.183572        0.231401
# min    1.001000e+03       0.000000        0.000000
# 25%    2.109100e+04      68.000000        0.094000
# 50%    4.208100e+04     358.000000        0.273000
# 75%    9.090012e+07    1375.000000        0.479000
# max    9.560004e+07  590502.000000        1.000000

# %% [markdown]
# # Seleccion

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %% [markdown]
# La columna a la izquierda del state es el index. Un dataframe tiene que tener un index, que es la manera de organizar los datos.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=24611, step=1)

# %% [markdown]
# podemos seleccionar una fila mediante su index.

# %%
df.loc[0]
# Out:
# state                        Alabama
# state_abbreviation                AL
# county                       Autauga
# fips                          1001.0
# party                       Democrat
# candidate             Bernie Sanders
# votes                            544
# fraction_votes                 0.182
# Name: 0, dtype: object

# %% [markdown]
# Importante, df.loc selecciona por indice, no por posición. Podemos cambiar el indice a cualquier otra cosa, otra columna o una lista separada, siempre que el nuevo indice tenga la misma longitud que el Dataframe

# %%
df2 = df.set_index("county")

# %%
df2.head()
# Out:
#            state state_abbreviation    fips     party        candidate  votes  \
# county
# Autauga  Alabama                 AL  1001.0  Democrat   Bernie Sanders    544
# Autauga  Alabama                 AL  1001.0  Democrat  Hillary Clinton   2387
# Baldwin  Alabama                 AL  1003.0  Democrat   Bernie Sanders   2694
# Baldwin  Alabama                 AL  1003.0  Democrat  Hillary Clinton   5290
# Barbour  Alabama                 AL  1005.0  Democrat   Bernie Sanders    222
#
#          fraction_votes
# county
# Autauga           0.182
# Autauga           0.800
# Baldwin           0.329
# Baldwin           0.647
# Barbour           0.078

# %%
df2.index
# Out:
# Index(['Autauga', 'Autauga', 'Baldwin', 'Baldwin', 'Barbour', 'Barbour',
#        'Bibb', 'Bibb', 'Blount', 'Blount',
#        ...
#        'Sweetwater-Carbon', 'Sweetwater-Carbon', 'Teton-Sublette',
#        'Teton-Sublette', 'Teton-Sublette', 'Teton-Sublette', 'Uinta-Lincoln',
#        'Uinta-Lincoln', 'Uinta-Lincoln', 'Uinta-Lincoln'],
#       dtype='object', name='county', length=24611)

# %% [markdown]
# Esto va a fallar por que df2 no tiene un indice numérico.

# %%
df2.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df2.loc[0]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# Ahora podemos seleccionar por condado

# %%
df2.loc["Los Angeles"]

# %% [markdown]
# Si queremos seleccionar por el numero de fila independientemente del índice, podemos usar `iloc`

# %%
df2.iloc[0]

# %% [markdown]
# Seleccionamos una columna mediante '[]' como si el dataframe fuese un diccionario

# %%
df["state"][:10]

# %% [markdown]
# si la columna tiene sintaxis  valida (sin espacios), se puede acceder como atributo siempre y cuando dicho atributo no exista en el dataframe

# %%
df.state[:10]

# %% [markdown]
# por ejemplo, si creamos una columna nueva de nombre `shape` (que ya es un atributo del dataframe), solo podemos acceder a dicha columna como si fuese un diccionario

# %%
df["shape"] = 1
df.head()

# %%
df.shape

# %% [markdown]
# Si seleccionamos una columna, obtenemos una Serie, si seleccionamos dos o más, obtenemos un dataframe.

# %%
type(df['county'])

# %%
type(df[["county", "candidate"]])

# %% [markdown]
# Podemos filtrar un dataframe de la misma forma que filtramos en numpy

# %%
df[df.votes>=590502]

# %% [markdown]
# podemos concatenar varias condiciones usando `&`

# %%
df[(df.county=="Manhattan") & (df.party=="Democrat")]

# %% [markdown]
# alternativamente podemos usar el método `query`

# %%
df.query("county=='Manhattan' and party=='Democrat'")

# %%
county = 'Manhattan'
df.query("county==@county and party=='Democrat'")

# %% [markdown]
# # Procesado

# %% [markdown]
# podemos usar `sort_values` para orderar el dataframe acorde al valor de una columna

# %%
df_sorted = df.sort_values(by="votes", ascending=False)
df_sorted.head()

# %%
df.groupby(["state", "party"])

# %%
df.groupby(["state", "party"])["votes"].sum()

# %% [markdown]
# podemos usar `apply` en una columna para obtener una nueva columna en función de sus valores

# %%
df['letra_inicial'] = df.state_abbreviation.apply(lambda s: s[0])

# %%
df.groupby("letra_inicial")["votes"].sum().sort_values()

# %% [markdown]
# Podemos unir dos dataframes en funcion de sus columnas comunes usando `merge`

# %%
# Descargamos datos de pobreza por condado en US en https://www.ers.usda.gov/data-products/county-level-data-sets/county-level-data-sets-download-data/
df_pobreza = pd.read_csv("PovertyEstimates.csv")

# %%
df_pobreza.head()

# %%
df = df.merge(df_pobreza, left_on="fips", right_on="FIPStxt")
df.head()

# %%
county_votes = df.groupby(["county","party"]).agg({
    "fraction_votes":"mean",
    "PCTPOVALL_2015": "mean"   
   }
)
county_votes

# %% [markdown]
# # Exportar

# %% [markdown]
# podemos escribir a excel,
#
# <div class="alert alert-block alert-alert">
# <b>ACTUALIZACION Mayo 2021</b> En general es mejor exportar a formato xlsx en vez de xls (que es el formato antiguo de Microsoft Excel).
# </div>
#
# Si ves este error,
#
# ``` FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   rick_morty.to_excel("rick_y_morty.xls", sheet_name="personajes")
# ```
#
# reemplaza el nombre `"rick_y_morty.xls"` por `"rick_y_morty.xlsx"`
#
# **para exportar a la version xlsx de excel (version actual, la version xls es una version antigua) se recomienda tener el paquete `openpyxl` instalado en vez de `xlwt`)**

# %%
rick_morty.to_excel("rick_y_morty.xlsx", sheet_name="personajes")

# %% [markdown]
# podemos leer de excel, necesitamos el paquete `xlrd`

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>ACTUALIZACION Mayo 2021:</b> "sheetname" fue reemplazado por "sheet_name"
# </div>

# %%
rick_morty2 = pd.read_excel("rick_y_morty.xlsx", sheet_name="personajes")

# %%
rick_morty2.head()
